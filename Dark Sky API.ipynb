# %%
from dotenv import load_dotenv
load_dotenv()
import os

API_KEY = os.getenv("DARKSKY_API_KEY")

# %%
# Using the URL on http://darksky.net/dev/account
# print out the current temperature 

import requests
response = requests.get(f'https://api.darksky.net/forecast/{API_KEY}/37.8267,-122.4233')
ds = response.json()
print(ds.keys())
print(ds['currently'])
print(ds['currently']['temperature'])
# Out:
# dict_keys(['latitude', 'longitude', 'timezone', 'currently', 'minutely', 'hourly', 'daily', 'flags', 'offset'])
# {'time': 1559866829, 'summary': 'Clear', 'icon': 'clear-day', 'nearestStormDistance': 0, 'precipIntensity': 0, 'precipProbability': 0, 'temperature': 58.04, 'apparentTemperature': 58.04, 'dewPoint': 46.98, 'humidity': 0.67, 'pressure': 1014.79, 'windSpeed': 11.53, 'windGust': 24.57, 'windBearing': 266, 'cloudCover': 0.19, 'uvIndex': 3, 'visibility': 8.66, 'ozone': 325.15}
# 58.04

# %%
response = requests.get(F'https://api.darksky.net/forecast/{API_KEY}/68,-101')
data = response.json()
data['currently']['temperature']
# Out:
# 31.11

# %%
# !touch .env

# %%
# !pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /Users/tbi/.pyenv/versions/3.6.5/lib/python3.6/site-packages
# You are using pip version 9.0.3, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
response.text
# Out:
# '{"latitude":68,"longitude":-101,"timezone":"America/Cambridge_Bay","currently":{"time":1559866829,"summary":"Mostly Cloudy","icon":"partly-cloudy-day","precipIntensity":0,"precipProbability":0,"temperature":31.11,"apparentTemperature":24.13,"dewPoint":28.53,"humidity":0.9,"pressure":1024.04,"windSpeed":7.43,"windGust":9.02,"windBearing":17,"cloudCover":0.63,"uvIndex":1,"visibility":10,"ozone":391.68},"hourly":{"summary":"Mostly cloudy throughout the day.","icon":"partly-cloudy-day","data":[{"time":1559865600,"summary":"Mostly Cloudy","icon":"partly-cloudy-day","precipIntensity":0,"precipProbability":0,"temperature":31.19,"apparentTemperature":24.15,"dewPoint":28.53,"humidity":0.9,"pressure":1024.05,"windSpeed":7.55,"windGust":9.16,"windBearing":18,"cloudCover":0.67,"uvIndex":1,"visibility":10,"ozone":390.76},{"time":1559869200,"summary":"Partly Cloudy","icon":"partly-cloudy-day","precipIntensity":0,"precipProbability":0,"temperature":30.96,"apparentTemperature":24.1,"dewPoint":28.53,"humidity":0.91,"pressure":1024.01,"windSpeed":7.2,"windGust":8.76,"windBearing":15,"cloudCover":0.55,"uvIndex":1,"visibility":10,"ozone":393.44},{"time":1559872800,"summary":"Partly Cloudy","icon":"partly-cloudy-day","precipIntensity":0,"precipProbability":0,"temperature":30.72,"apparentTemperature":24.06,"dewPoint":28.41,"humidity":0.91,"pressure":1023.92,"windSpeed":6.85,"windGust":8.38,"windBearing":10,"cloudCover":0.41,"uvIndex":0,"visibility":10,"ozone":395.92},{"time":1559876400,"summary":"Partly Cloudy","icon":"partly-cloudy-day","precipIntensity":0,"precipProbability":0,"temperature":30.12,"apparentTemperature":23.64,"dewPoint":28.06,"humidity":0.92,"pressure":1023.82,"windSpeed":6.45,"windGust":8.05,"windBearing":9,"cloudCover":0.33,"uvIndex":0,"visibility":10,"ozone":397.66},{"time":1559880000,"summary":"Partly Cloudy","icon":"partly-cloudy-day","precipIntensity":0,"precipProbability":0,"temperature":28.97,"apparentTemperature":22.66,"dewPoint":27.35,"humidity":0.94,"pressure":1023.73,"windSpeed":5.95,"windGust":7.96,"windBearing":10,"cloudCover":0.42,"uvIndex":0,"visibility":10,"ozone":398.53},{"time":1559883600,"summary":"Partly Cloudy","icon":"partly-cloudy-day","precipIntensity":0,"precipProbability":0,"temperature":27.54,"apparentTemperature":21.47,"dewPoint":26.38,"humidity":0.95,"pressure":1023.69,"windSpeed":5.38,"windGust":7.96,"windBearing":13,"cloudCover":0.54,"uvIndex":0,"visibility":9.37,"ozone":398.75},{"time":1559887200,"summary":"Mostly Cloudy","icon":"partly-cloudy-day","precipIntensity":0,"precipProbability":0,"temperature":26.47,"apparentTemperature":20.72,"dewPoint":25.39,"humidity":0.96,"pressure":1023.64,"windSpeed":4.86,"windGust":7.74,"windBearing":15,"cloudCover":0.63,"uvIndex":0,"visibility":6.99,"ozone":398.53},{"time":1559890800,"summary":"Mostly Cloudy","icon":"partly-cloudy-day","precipIntensity":0,"precipProbability":0,"temperature":25.57,"apparentTemperature":20.2,"dewPoint":24.44,"humidity":0.95,"pressure":1023.64,"windSpeed":4.38,"windGust":7.07,"windBearing":13,"cloudCover":0.64,"uvIndex":0,"visibility":6.96,"ozone":397.88},{"time":1559894400,"summary":"Mostly Cloudy","icon":"partly-cloudy-day","precipIntensity":0,"precipProbability":0,"temperature":24.89,"apparentTemperature":19.99,"dewPoint":23.48,"humidity":0.94,"pressure":1023.73,"windSpeed":3.9,"windGust":6.19,"windBearing":10,"cloudCover":0.64,"uvIndex":0,"visibility":6.93,"ozone":396.9},{"time":1559898000,"summary":"Mostly Cloudy","icon":"partly-cloudy-day","precipIntensity":0,"precipProbability":0,"temperature":24.87,"apparentTemperature":20.32,"dewPoint":23.09,"humidity":0.93,"pressure":1023.73,"windSpeed":3.63,"windGust":5.38,"windBearing":7,"cloudCover":0.64,"uvIndex":0,"visibility":6.94,"ozone":396.03},{"time":1559901600,"summary":"Mostly Cloudy","icon":"partly-cloudy-day","precipIntensity":0,"precipProbability":0,"temperature":25.95,"apparentTemperature":21.49,"dewPoint":23.8,"humidity":0.91,"pressure":1023.69,"windSpeed":3.68,"windGust":4 ...

# %%
# !touch .super_secret_file
